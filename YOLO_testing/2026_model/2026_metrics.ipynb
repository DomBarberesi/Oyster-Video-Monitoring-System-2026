# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO
import pandas as pd

# %%
model_path = "/home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/models/yolov8s_2026/weights/best.pt"
dataset = "/home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-2/data.yaml"
results = []
model = YOLO(model_path)

result = model.val(data=dataset, conf=0.25)
results.append({"Run":"yolov8s Val", "Precision":round(result.box.p.mean().item(), 3),
    "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})
# Out:
# Ultralytics 8.4.71 🚀 Python-3.14.5 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4080, 15935MiB)
# Model summary (fused): 73 layers, 11,126,745 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4171.3±1228.8 MB/s, size: 34.9 KB)
# val: Scanning /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-2/valid/labels.cache... 362 images, 139 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 362/362 116.8Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 2621, len(boxes) = 2857. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 23/23 12.6it/s 1.8s0.0s
#                    all        362       2857      0.587      0.519      0.449      0.291
# ...

# %%
result = model.val(data=dataset, split="test", conf=0.25)
results.append({"Run":"yolov8s Test", "Precision":round(result.box.p.mean().item(), 3),
    "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})
# Out:
# Ultralytics 8.4.71 🚀 Python-3.14.5 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4080, 15935MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3704.8±1380.7 MB/s, size: 32.2 KB)
# val: Scanning /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-2/test/labels.cache... 1929 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1929/1929 1.3Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 121/121 15.2it/s 8.0s0.1s
#                    all       1929      24046      0.417      0.358      0.193      0.107
#          Oyster-Closed       1799       7829      0.489       0.32      0.205      0.126
#   Oyster-Indeterminate       1929      12534      0.299       0.37      0.152     0.0676
#            Oyster-Open       1401       3683      0.464      0.385      0.222      0.128
# Speed: 0.3ms preprocess, 2.3ms inference, 0.0ms loss, 0.6ms postprocess per image
# ...

# %%
model_path = "/home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/models/yolov8m_2026/weights/best.pt"
model = YOLO(model_path)

result = model.val(data=dataset, conf=0.25)
results.append({"Run":"yolov8m Val", "Precision":round(result.box.p.mean().item(), 3),
    "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})
# Out:
# Ultralytics 8.4.71 🚀 Python-3.14.5 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4080, 15935MiB)
# Model summary (fused): 93 layers, 25,841,497 parameters, 0 gradients, 78.7 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4600.9±1213.8 MB/s, size: 42.0 KB)
# val: Scanning /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-2/valid/labels.cache... 362 images, 139 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 362/362 303.7Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 2621, len(boxes) = 2857. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 23/23 8.8it/s 2.6s<0.1s
#                    all        362       2857      0.588       0.55      0.453      0.293
# ...

# %%
result = model.val(data=dataset, split="test", conf=0.25)
results.append({"Run":"yolov8m Test", "Precision":round(result.box.p.mean().item(), 3),
    "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})
# Out:
# Ultralytics 8.4.71 🚀 Python-3.14.5 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4080, 15935MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3316.6±416.4 MB/s, size: 25.7 KB)
# val: Scanning /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-2/test/labels.cache... 1929 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1929/1929 1.0Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 121/121 9.3it/s 13.0s<0.2s
#                    all       1929      24046      0.432      0.369      0.219      0.124
#          Oyster-Closed       1799       7829      0.513      0.349      0.228      0.142
#   Oyster-Indeterminate       1929      12534      0.324      0.352      0.152     0.0694
#            Oyster-Open       1401       3683      0.459      0.406      0.277       0.16
# Speed: 0.3ms preprocess, 5.2ms inference, 0.0ms loss, 0.3ms postprocess per image
# ...

# %%
model_path = "/home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/models/yolov8n_2026/weights/best.pt"
model = YOLO(model_path)

result = model.val(data=dataset, conf=0.25)
results.append({"Run":"yolov8n Val", "Precision":round(result.box.p.mean().item(), 3),
    "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})
# Out:
# Ultralytics 8.4.71 🚀 Python-3.14.5 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4080, 15935MiB)
# Model summary (fused): 73 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4133.7±603.8 MB/s, size: 36.2 KB)
# val: Scanning /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-2/valid/labels.cache... 362 images, 139 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 362/362 216.9Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 2621, len(boxes) = 2857. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 23/23 15.2it/s 1.5s0.2s
#                    all        362       2857      0.539      0.535      0.428      0.276
# ...

# %%
result = model.val(data=dataset, split="test", conf=0.25)
results.append({"Run":"yolov8n Test", "Precision":round(result.box.p.mean().item(), 3),
    "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})
# Out:
# Ultralytics 8.4.71 🚀 Python-3.14.5 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4080, 15935MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3182.0±970.7 MB/s, size: 35.8 KB)
# val: Scanning /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-2/test/labels.cache... 1929 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1929/1929 1.2Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 121/121 19.9it/s 6.1s0.1s
#                    all       1929      24046      0.391      0.347      0.186      0.108
#          Oyster-Closed       1799       7829      0.371      0.242      0.122     0.0743
#   Oyster-Indeterminate       1929      12534      0.333      0.457      0.191     0.0937
#            Oyster-Open       1401       3683      0.467      0.342      0.243      0.157
# Speed: 0.3ms preprocess, 1.3ms inference, 0.0ms loss, 0.6ms postprocess per image
# ...

# %%
model_path = "/home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/models/yolov8s_2026_v2/weights/best.pt"
model = YOLO(model_path)

result = model.val(data=dataset, conf=0.25)
results.append({"Run":"yolov8s_v2 Val", "Precision":round(result.box.p.mean().item(), 3),
    "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})
# Out:
# Ultralytics 8.4.71 🚀 Python-3.14.5 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4080, 15935MiB)
# Model summary (fused): 73 layers, 11,126,745 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3851.1±1110.9 MB/s, size: 38.8 KB)
# val: Scanning /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-2/valid/labels.cache... 362 images, 139 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 362/362 253.1Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 2621, len(boxes) = 2857. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 23/23 12.3it/s 1.9s0.1s
#                    all        362       2857      0.599      0.571      0.488      0.321
# ...

# %%
result = model.val(data=dataset, split="test", conf=0.25)
results.append({"Run":"yolov8s_v2 Test", "Precision":round(result.box.p.mean().item(), 3),
    "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})
# Out:
# Ultralytics 8.4.71 🚀 Python-3.14.5 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4080, 15935MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3215.9±1154.0 MB/s, size: 33.5 KB)
# val: Scanning /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-2/test/labels.cache... 1929 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1929/1929 899.0Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 121/121 15.0it/s 8.1s0.0s
#                    all       1929      24046      0.384      0.395      0.243      0.141
#          Oyster-Closed       1799       7829      0.426      0.451      0.341      0.224
#   Oyster-Indeterminate       1929      12534      0.412      0.399      0.203     0.0909
#            Oyster-Open       1401       3683      0.315      0.336      0.184      0.109
# Speed: 0.3ms preprocess, 2.6ms inference, 0.0ms loss, 0.3ms postprocess per image
# ...

# %%
model_path = "/home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/models/yolov8m_2026_v2/weights/best.pt"
model = YOLO(model_path)

result = model.val(data=dataset, conf=0.25)
results.append({"Run":"yolov8m_v2 Val", "Precision":round(result.box.p.mean().item(), 3),
    "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})
# Out:
# Ultralytics 8.4.71 🚀 Python-3.14.5 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4080, 15935MiB)
# Model summary (fused): 93 layers, 25,841,497 parameters, 0 gradients, 78.7 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3301.3±1508.0 MB/s, size: 26.3 KB)
# val: Scanning /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-2/valid/labels.cache... 362 images, 139 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 362/362 303.7Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 2621, len(boxes) = 2857. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 23/23 8.4it/s 2.7s<0.1s
#                    all        362       2857      0.568      0.586      0.485      0.321
# ...

# %%
result = model.val(data=dataset, split="test", conf=0.25)
results.append({"Run":"yolov8m_v2 Test", "Precision":round(result.box.p.mean().item(), 3),
    "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})
# Out:
# Ultralytics 8.4.71 🚀 Python-3.14.5 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4080, 15935MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1577.6±381.0 MB/s, size: 34.2 KB)
# val: Scanning /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-2/test/labels.cache... 1929 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1929/1929 1.3Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 121/121 9.3it/s 13.0s<0.2s
#                    all       1929      24046      0.394      0.406      0.234      0.132
#          Oyster-Closed       1799       7829      0.449      0.459      0.303      0.195
#   Oyster-Indeterminate       1929      12534      0.368      0.376      0.168     0.0778
#            Oyster-Open       1401       3683      0.365      0.382      0.232      0.123
# Speed: 0.3ms preprocess, 5.2ms inference, 0.0ms loss, 0.3ms postprocess per image
# ...

# %%
model_path = "/home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/models/yolov8n_2026_v2/weights/best.pt"
model = YOLO(model_path)

result = model.val(data=dataset, conf=0.25)
results.append({"Run":"yolov8n_v2 Val", "Precision":round(result.box.p.mean().item(), 3),
    "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})
# Out:
# Ultralytics 8.4.71 🚀 Python-3.14.5 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4080, 15935MiB)
# Model summary (fused): 73 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4585.9±1241.4 MB/s, size: 39.3 KB)
# val: Scanning /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-2/valid/labels.cache... 362 images, 139 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 362/362 253.1Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 2621, len(boxes) = 2857. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 23/23 14.7it/s 1.6s0.1s
#                    all        362       2857      0.587       0.54      0.451      0.297
# ...

# %%
result = model.val(data=dataset, split="test", conf=0.25)
results.append({"Run":"yolov8n_v2 Test", "Precision":round(result.box.p.mean().item(), 3),
    "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})
# Out:
# Ultralytics 8.4.71 🚀 Python-3.14.5 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4080, 15935MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1626.3±385.9 MB/s, size: 33.3 KB)
# val: Scanning /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-2/test/labels.cache... 1929 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1929/1929 1.2Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 121/121 20.0it/s 6.1s0.1s
#                    all       1929      24046      0.396      0.409      0.241      0.132
#          Oyster-Closed       1799       7829      0.383      0.448       0.33      0.204
#   Oyster-Indeterminate       1929      12534      0.401      0.451      0.218     0.0988
#            Oyster-Open       1401       3683      0.403      0.327      0.175     0.0946
# Speed: 0.3ms preprocess, 1.3ms inference, 0.0ms loss, 0.6ms postprocess per image
# ...

# %%
model_path = "/home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/models/yolov8s_2026_v3/weights/best.pt"
dataset = "/home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-4/data.yaml"
model = YOLO(model_path)

result = model.val(data=dataset, conf=0.25)
results.append({"Run":"yolov8s_v3 Val", "Precision":round(result.box.p.mean().item(), 3),
    "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})
# Out:
# Ultralytics 8.4.71 🚀 Python-3.14.5 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4080, 15935MiB)
# Model summary (fused): 73 layers, 11,126,358 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3698.5±1243.6 MB/s, size: 29.4 KB)
# val: Scanning /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-4/valid/labels.cache... 300 images, 60 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 300/300 179.8Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 218, len(boxes) = 1417. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 13.8it/s 1.4s0.0s
#                    all        300       1417      0.572        0.5      0.402       0.31
# ...

# %%
result = model.val(data=dataset, split="test", conf=0.25)
results.append({"Run":"yolov8s_v3 Test", "Precision":round(result.box.p.mean().item(), 3),
    "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})
# Out:
# Ultralytics 8.4.71 🚀 Python-3.14.5 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4080, 15935MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1635.0±591.1 MB/s, size: 30.1 KB)
# val: Scanning /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-4/test/labels.cache... 1929 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1929/1929 1.2Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 121/121 15.9it/s 7.6s0.1s
#                    all       1929      24101      0.521       0.56      0.425       0.25
#          Oyster-Closed       1929      18043      0.528      0.606      0.464      0.267
#            Oyster-Open       1465       6058      0.514      0.515      0.386      0.233
# Speed: 0.3ms preprocess, 2.2ms inference, 0.0ms loss, 0.4ms postprocess per image
# ...

# %%
model_path = "/home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/models/yolov8m_2026_v3/weights/best.pt"
model = YOLO(model_path)

result = model.val(data=dataset, conf=0.25)
results.append({"Run":"yolov8m_v3 Val", "Precision":round(result.box.p.mean().item(), 3),
    "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})
# Out:
# Ultralytics 8.4.71 🚀 Python-3.14.5 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4080, 15935MiB)
# Model summary (fused): 93 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4192.0±894.1 MB/s, size: 31.6 KB)
# val: Scanning /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-4/valid/labels.cache... 300 images, 60 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 300/300 179.8Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 218, len(boxes) = 1417. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 9.2it/s 2.1s<0.2s
#                    all        300       1417      0.593      0.463      0.377      0.304
# ...

# %%
result = model.val(data=dataset, split="test", conf=0.25)
results.append({"Run":"yolov8m_v3 Test", "Precision":round(result.box.p.mean().item(), 3),
    "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})
# Out:
# Ultralytics 8.4.71 🚀 Python-3.14.5 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4080, 15935MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3286.4±1071.7 MB/s, size: 24.8 KB)
# val: Scanning /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-4/test/labels.cache... 1929 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1929/1929 1.2Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 121/121 9.7it/s 12.5s<0.1s
#                    all       1929      24101      0.543      0.558       0.43      0.258
#          Oyster-Closed       1929      18043      0.548      0.571      0.436      0.251
#            Oyster-Open       1465       6058      0.538      0.544      0.424      0.264
# Speed: 0.3ms preprocess, 4.8ms inference, 0.0ms loss, 0.4ms postprocess per image
# ...

# %%
model_path = "/home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/models/yolov8s_2026_v4/weights/best.pt"
model = YOLO(model_path)

result = model.val(data=dataset, conf=0.25)
results.append({"Run":"yolov8s_v4 Val", "Precision":round(result.box.p.mean().item(), 3),
    "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})
# Out:
# Ultralytics 8.4.71 🚀 Python-3.14.5 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4080, 15935MiB)
# Model summary (fused): 73 layers, 11,126,358 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4661.1±1231.3 MB/s, size: 47.4 KB)
# val: Scanning /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-4/valid/labels.cache... 300 images, 60 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 300/300 139.8Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 218, len(boxes) = 1417. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 13.1it/s 1.4s0.1s
#                    all        300       1417      0.545      0.579      0.475      0.312
# ...

# %%
result = model.val(data=dataset, split="test", conf=0.25)
results.append({"Run":"yolov8s_v4 Test", "Precision":round(result.box.p.mean().item(), 3),
    "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})
# Out:
# Ultralytics 8.4.71 🚀 Python-3.14.5 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4080, 15935MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3531.0±1482.8 MB/s, size: 28.9 KB)
# val: Scanning /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-4/test/labels.cache... 1929 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1929/1929 1.0Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 121/121 15.6it/s 7.8s0.0s
#                    all       1929      24101      0.444      0.533      0.359      0.195
#          Oyster-Closed       1929      18043      0.467      0.612      0.427      0.228
#            Oyster-Open       1465       6058      0.421      0.453       0.29      0.163
# Speed: 0.3ms preprocess, 2.2ms inference, 0.0ms loss, 0.4ms postprocess per image
# ...

# %%
model_path = "/home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/models/yolov8m_2026_v4/weights/best.pt"
model = YOLO(model_path)

result = model.val(data=dataset, conf=0.25)
results.append({"Run":"yolov8m_v4 Val", "Precision":round(result.box.p.mean().item(), 3),
    "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})
# Out:
# Ultralytics 8.4.71 🚀 Python-3.14.5 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4080, 15935MiB)
# Model summary (fused): 93 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4552.3±1865.9 MB/s, size: 53.5 KB)
# val: Scanning /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-4/valid/labels.cache... 300 images, 60 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 300/300 251.7Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 218, len(boxes) = 1417. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 19/19 9.2it/s 2.1s<0.2s
#                    all        300       1417      0.613      0.522       0.44      0.318
# ...

# %%
result = model.val(data=dataset, split="test", conf=0.25)
results.append({"Run":"yolov8m_v4 Test", "Precision":round(result.box.p.mean().item(), 3),
    "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})
# Out:
# Ultralytics 8.4.71 🚀 Python-3.14.5 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4080, 15935MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3391.1±1131.3 MB/s, size: 39.0 KB)
# val: Scanning /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-4/test/labels.cache... 1929 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1929/1929 1.0Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 121/121 9.6it/s 12.6s<0.2s
#                    all       1929      24101       0.52      0.494       0.37      0.201
#          Oyster-Closed       1929      18043      0.532       0.59      0.447      0.236
#            Oyster-Open       1465       6058      0.509      0.397      0.292      0.166
# Speed: 0.3ms preprocess, 4.6ms inference, 0.0ms loss, 0.6ms postprocess per image
# ...

# %%
df = pd.DataFrame(results)
df_sorted = df.sort_values(by="mAP@0.5", ascending=False).reset_index(drop=True)
print("\n2025 Model Metrics")
print(df_sorted)
# Out:
# 2025 Model Metrics
#                 Run  Precision  Recall  mAP@0.5
# 0    yolov8s_v2 Val      0.599   0.571    0.488
# 1    yolov8m_v2 Val      0.568   0.586    0.485
# 2    yolov8s_v4 Val      0.545   0.579    0.475
# 3       yolov8m Val      0.588   0.550    0.453
# 4    yolov8n_v2 Val      0.587   0.540    0.451
# 5       yolov8s Val      0.587   0.519    0.449
# 6    yolov8m_v4 Val      0.613   0.522    0.440
# 7   yolov8m_v3 Test      0.543   0.558    0.430
# 8       yolov8n Val      0.539   0.535    0.428
# 9   yolov8s_v3 Test      0.521   0.560    0.425
# 10   yolov8s_v3 Val      0.572   0.500    0.402
# 11   yolov8m_v3 Val      0.593   0.463    0.377
# 12  yolov8m_v4 Test      0.520   0.494    0.370
# 13  yolov8s_v4 Test      0.444   0.533    0.359
# 14  yolov8s_v2 Test      0.384   0.395    0.243
# 15  yolov8n_v2 Test      0.396   0.409    0.241
# 16  yolov8m_v2 Test      0.394   0.406    0.234
# 17     yolov8m Test      0.432   0.369    0.219
# ...

# %%
# %pip install onnx
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install onnxslim
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install onnxruntime
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install tensorflowjs
# Out:
# ...
#   Using cached packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# ...
# Using cached packaging-23.2-py3-none-any.whl (53 kB)
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 26.2
#     Uninstalling packaging-26.2:
#       Successfully uninstalled packaging-26.2
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
model = YOLO("/home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/models/yolov8m_2026_v3/weights/best.pt")
model.export(format="tfjs")
# Out:
# WARNING ⚠️ format='tfjs' is deprecated as of 8.4.83 and has been replaced by the unified Google LiteRT format. Exporting format='litert' instead. See https://docs.ultralytics.com/integrations/litert/
# Ultralytics 8.4.89 🚀 Python-3.11.15 torch-2.12.1+cu130 CPU (13th Gen Intel Core i9-13900KF)
# Model summary (fused): 93 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
#
# PyTorch: starting from '/home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/models/yolov8m_2026_v3/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 6, 8400) (49.6 MB)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1783351038.972614 1726241 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ...
