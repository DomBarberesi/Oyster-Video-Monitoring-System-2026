# %%
from IPython import display
display.clear_output()

# %%
# %pip install pandas
display.clear_output()

# %%
# %pip install ultralytics
display.clear_output()

# %%
from ultralytics import YOLO
import pandas as pd

# %% [markdown]
# Run models on validation and test sets

# %%
models = ["yolov8s_2026", "yolov8m_2026", "yolov8n_2026",
        "yolov8s_2026_v2", "yolov8m_2026_v2", "yolov8n_2026_v2",
        "yolov8s_2026_v3", "yolov8m_2026_v3",
        "yolov8s_2026_v4", "yolov8m_2026_v4",
        "yolov8s_2026_v5", "yolov8s_2026_v6"]
results = []

# %%
dataset = "/home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-2/data.yaml"

# %%
for i in range(6):
    model_path = f"/home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/models/{models[i]}/weights/best.pt"
    model = YOLO(model_path)
    
    result = model.val(data=dataset, conf=0.25)
    results.append({"Run":f"{models[i]} Val", "Precision":round(result.box.p.mean().item(), 3),
        "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})
    
    result = model.val(data=dataset, split="test", conf=0.25)
    results.append({"Run":f"{models[i]} Test", "Precision":round(result.box.p.mean().item(), 3),
        "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})

display.clear_output()

# %%
dataset = "/home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/Oyster-Dataset-2026-2/data.yaml"

# %%
for i in range(6, 12):
    model_path = f"/home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/models/{models[i]}/weights/best.pt"
    model = YOLO(model_path)
    
    result = model.val(data=dataset, conf=0.25)
    results.append({"Run":f"{models[i]} Val", "Precision":round(result.box.p.mean().item(), 3),
        "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})
    
    result = model.val(data=dataset, split="test", conf=0.25)
    results.append({"Run":f"{models[i]} Test", "Precision":round(result.box.p.mean().item(), 3),
        "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})

display.clear_output()

# %% [markdown]
# Compare all model metrics

# %%
df = pd.DataFrame(results)
df_sorted = df.sort_values(by="mAP@0.5", ascending=False).reset_index(drop=True)
print("\n2025 Model Metrics")
print(df_sorted)
# Out:
# 2025 Model Metrics
#                      Run  Precision  Recall  mAP@0.5
# 0    yolov8s_2026_v6 Val      0.656   0.579    0.639
# 1    yolov8s_2026_v5 Val      0.766   0.519    0.631
# 2    yolov8m_2026_v4 Val      0.637   0.573    0.617
# 3    yolov8m_2026_v3 Val      0.641   0.535    0.598
# 4    yolov8s_2026_v3 Val      0.645   0.536    0.594
# 5    yolov8m_2026_v2 Val      0.568   0.586    0.592
# 6    yolov8s_2026_v2 Val      0.599   0.571    0.590
# 7    yolov8s_2026_v4 Val      0.547   0.563    0.576
# 8    yolov8n_2026_v2 Val      0.587   0.540    0.571
# 9   yolov8s_2026_v6 Test      0.625   0.512    0.565
# 10      yolov8m_2026 Val      0.588   0.550    0.563
# 11      yolov8s_2026 Val      0.587   0.519    0.559
# 12  yolov8s_2026_v5 Test      0.574   0.534    0.558
# 13      yolov8n_2026 Val      0.539   0.535    0.552
# 14  yolov8s_2026_v3 Test      0.543   0.524    0.538
# 15  yolov8m_2026_v3 Test      0.568   0.521    0.536
# 16  yolov8m_2026_v4 Test      0.537   0.483    0.493
# 17  yolov8s_2026_v4 Test      0.466   0.503    0.458
# 18  yolov8n_2026_v2 Test      0.396   0.409    0.358
# 19     yolov8m_2026 Test      0.432   0.369    0.356
# 20  yolov8s_2026_v2 Test      0.384   0.395    0.352
# 21  yolov8m_2026_v2 Test      0.394   0.406    0.351
# 22     yolov8s_2026 Test      0.417   0.358    0.327
# 23     yolov8n_2026 Test      0.391   0.347    0.313

# %% [markdown]
# Export best models to tfjs format

# %%
# %pip install onnx
# Out:
# Requirement already satisfied: onnx in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (1.19.1)
# Requirement already satisfied: numpy>=1.22 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from onnx) (2.1.3)
# Requirement already satisfied: protobuf>=4.25.1 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from onnx) (5.29.6)
# Requirement already satisfied: typing_extensions>=4.7.1 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from onnx) (4.16.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from onnx) (0.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install onnxslim
# Out:
# Requirement already satisfied: onnxslim in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (0.1.94)
# Requirement already satisfied: colorama in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from onnxslim) (0.4.6)
# Requirement already satisfied: ml-dtypes in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from onnxslim) (0.5.1)
# Requirement already satisfied: onnx in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from onnxslim) (1.19.1)
# Requirement already satisfied: packaging in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from onnxslim) (23.2)
# Requirement already satisfied: sympy>=1.13.1 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from onnxslim) (1.14.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from sympy>=1.13.1->onnxslim) (1.3.0)
# Requirement already satisfied: numpy>=1.21 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from ml-dtypes->onnxslim) (2.1.3)
# Requirement already satisfied: protobuf>=4.25.1 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from onnx->onnxslim) (5.29.6)
# Requirement already satisfied: typing_extensions>=4.7.1 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from onnx->onnxslim) (4.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install onnxruntime
# Out:
# Requirement already satisfied: onnxruntime in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (1.23.0)
# Requirement already satisfied: coloredlogs in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from onnxruntime) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from onnxruntime) (25.12.19)
# Requirement already satisfied: numpy>=1.21.6 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from onnxruntime) (2.1.3)
# Requirement already satisfied: packaging in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from onnxruntime) (23.2)
# Requirement already satisfied: protobuf in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from onnxruntime) (5.29.6)
# Requirement already satisfied: sympy in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from onnxruntime) (1.14.0)
# Requirement already satisfied: humanfriendly>=9.1 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from coloredlogs->onnxruntime) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from sympy->onnxruntime) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install tensorflowjs
# Out:
# Requirement already satisfied: tensorflowjs in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (4.22.0)
# Requirement already satisfied: flax>=0.7.2 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from tensorflowjs) (0.12.7)
# Requirement already satisfied: importlib_resources>=5.9.0 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from tensorflowjs) (7.1.0)
# Requirement already satisfied: jax>=0.4.13 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from tensorflowjs) (0.10.2)
# Requirement already satisfied: jaxlib>=0.4.13 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from tensorflowjs) (0.10.2)
# Requirement already satisfied: tensorflow<3,>=2.13.0 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from tensorflowjs) (2.19.0)
# Requirement already satisfied: tf-keras>=2.13.0 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from tensorflowjs) (2.19.0)
# Requirement already satisfied: tensorflow-decision-forests>=1.5.0 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from tensorflowjs) (1.12.0)
# Requirement already satisfied: six<2,>=1.16.0 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from tensorflowjs) (1.17.0)
# Requirement already satisfied: tensorflow-hub>=0.16.1 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from tensorflowjs) (0.16.1)
# Requirement already satisfied: packaging~=23.1 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from tensorflowjs) (23.2)
# Requirement already satisfied: absl-py>=1.0.0 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (2.5.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (5.29.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (2.32.5)
# Requirement already satisfied: setuptools in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (83.0.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (4.16.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (2.2.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.82.1)
# Requirement already satisfied: tensorboard~=2.19.0 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (3.15.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (2.1.3)
# Requirement already satisfied: h5py>=3.11.0 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (3.11.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (0.5.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (0.37.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (2.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (2026.6.17)
# Requirement already satisfied: markdown>=2.6.8 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from tensorboard~=2.19.0->tensorflow<3,>=2.13.0->tensorflowjs) (3.10.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from tensorboard~=2.19.0->tensorflow<3,>=2.13.0->tensorflowjs) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from tensorboard~=2.19.0->tensorflow<3,>=2.13.0->tensorflowjs) (3.1.8)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from astunparse>=1.6.0->tensorflow<3,>=2.13.0->tensorflowjs) (0.45.1)
# Requirement already satisfied: msgpack in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from flax>=0.7.2->tensorflowjs) (1.2.1)
# Requirement already satisfied: optax in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from flax>=0.7.2->tensorflowjs) (0.2.8)
# Requirement already satisfied: orbax-checkpoint in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from flax>=0.7.2->tensorflowjs) (0.12.1)
# Requirement already satisfied: tensorstore in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from flax>=0.7.2->tensorflowjs) (0.1.84)
# Requirement already satisfied: rich>=11.1 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from flax>=0.7.2->tensorflowjs) (15.0.0)
# Requirement already satisfied: PyYAML>=5.4.1 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from flax>=0.7.2->tensorflowjs) (6.0.3)
# Requirement already satisfied: treescope>=0.1.7 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from flax>=0.7.2->tensorflowjs) (0.1.10)
# Requirement already satisfied: scipy>=1.14 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from jax>=0.4.13->tensorflowjs) (1.17.1)
# Requirement already satisfied: namex in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from keras>=3.5.0->tensorflow<3,>=2.13.0->tensorflowjs) (0.1.0)
# Requirement already satisfied: optree in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from keras>=3.5.0->tensorflow<3,>=2.13.0->tensorflowjs) (0.19.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from rich>=11.1->flax>=0.7.2->tensorflowjs) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from rich>=11.1->flax>=0.7.2->tensorflowjs) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax>=0.7.2->tensorflowjs) (0.1.2)
# Requirement already satisfied: pandas in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (3.0.3)
# Requirement already satisfied: wurlitzer in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (3.1.1)
# Requirement already satisfied: ydf>=0.11.0 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (0.16.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow<3,>=2.13.0->tensorflowjs) (3.0.3)
# Requirement already satisfied: etils[epath,epy] in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (1.14.0)
# Requirement already satisfied: prometheus-client>=0.20.0 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (0.25.0)
# Requirement already satisfied: aiofiles in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (25.1.0)
# Requirement already satisfied: humanize in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (4.16.0)
# Requirement already satisfied: simplejson>=3.16.0 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (4.1.1)
# Requirement already satisfied: psutil in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (5.9.5)
# Requirement already satisfied: uvloop in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (0.22.1)
# Requirement already satisfied: fsspec in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.7.2->tensorflowjs) (2026.6.0)
# Requirement already satisfied: zipp in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.7.2->tensorflowjs) (4.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2.9.0.post0)
# Note: you may need to restart the kernel to use updated packages.

# %%
model = YOLO("/home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/models/yolov8s_2026_v5/weights/best.pt")
model.export(format="saved_model")
# Out:
# Ultralytics 8.4.0 🚀 Python-3.11.15 torch-2.13.0+cu130 CPU (13th Gen Intel Core i9-13900KF)
# Model summary (fused): 73 layers, 11,126,358 parameters, 0 gradients, 28.4 GFLOPs
#
# PyTorch: starting from '/home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/models/yolov8s_2026_v5/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 6, 8400) (21.5 MB)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1784231840.476415 3816361 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1784231840.487350 3816361 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1784231840.565790 3816361 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1784231840.565802 3816361 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1784231840.565803 3816361 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1784231840.565804 3816361 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# TensorFlow SavedModel: starting export with tensorflow 2.19.0...
#
# ONNX: starting export with onnx 1.19.1 opset 22...
# /home/reuekennedy/Oyster-Video-Monitoring-System-2026/.venv/lib64/python3.11/site-packages/torch/onnx/_internal/torchscript_exporter/utils.py:547: OnnxExporterWarning: Exporting to ONNX opset version 22 is not supported. by 'torch.onnx.export()'. The highest opset version supported is 20. To use a newer opset version, consider 'torch.onnx.export(..., dynamo=True)'.
#   _export(
# ONNX: slimming with onnxslim 0.1.94...
# ONNX: export success ✅ 0.7s, saved as '/home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/models/yolov8s_2026_v5/weights/best.onnx' (42.7 MB)
# TensorFlow SavedModel: starting TFLite export with onnx2tf 1.29.24...
# W0000 00:00:1784231843.354629 3816361 gpu_device.cc:2341] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Saved artifact at '/home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/models/yolov8s_2026_v5/weights/best_saved_model'. The following endpoints are available:
#
# * Endpoint 'serving_default'
#   inputs_0 (POSITIONAL_ONLY): TensorSpec(shape=(1, 640, 640, 3), dtype=tf.float32, name='images')
# Output Type:
#   TensorSpec(shape=(1, 6, 8400), dtype=tf.float32, name=None)
# Captures:
#   139622776180368: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   139622776181520: TensorSpec(shape=(3, 3, 3, 32), dtype=tf.float32, name=None)
#   139622776182480: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   139622776186320: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   139622776182672: TensorSpec(shape=(3, 3, 32, 64), dtype=tf.float32, name=None)
#   139622776187280: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   139622776187664: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   139622776187472: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   139622776178640: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139622776187856: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139622776189584: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   139622776190544: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   139622776188048: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   139622776189392: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   139622776188240: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139622776188432: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139625362281040: TensorSpec(shape=(1, 1, 96, 64), dtype=tf.float32, name=None)
#   139625362281424: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   139625362278928: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   139625362280848: TensorSpec(shape=(3, 3, 64, 128), dtype=tf.float32, name=None)
#   139625362281232: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   139625362279312: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   139625362280272: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   139622776192656: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139622776184016: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139625362278736: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   139625362280464: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   139625362282192: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   139625362281808: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   139622776177872: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   139622776192848: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   139622776192272: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   139622776191120: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   139625362278352: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139625362277392: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139625025569040: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   139625025568848: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   139625025569808: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   139625025569232: TensorSpec(shape=(3, 3, 128, 256), dtype=tf.float32, name=None)
#   139625025569616: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   139625025570000: TensorSpec(shape=(1, 1, 256, 256), dtype=tf.float32, name=None)
#   139625025570192: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   139625025570768: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139625025570576: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139625025571536: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   139625025572880: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   139625025570384: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   139625025569424: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   139625025573072: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   139625025573264: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   139625025571728: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   139625025572304: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   139625025570960: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139625025571152: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139625025572112: TensorSpec(shape=(1, 1, 512, 256), dtype=tf.float32, name=None)
#   139625025573456: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   139625025574224: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   139625025573648: TensorSpec(shape=(3, 3, 256, 512), dtype=tf.float32, name=None)
#   139625025574032: TensorSpec(shape=(512,), dtype=tf.float32, name=None)
#   139625025574416: TensorSpec(shape=(1, 1, 512, 512), dtype=tf.float32, name=None)
#   139625025574608: TensorSpec(shape=(512,), dtype=tf.float32, name=None)
#   139625025575184: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139625025574800: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139625025575952: TensorSpec(shape=(3, 3, 256, 256), dtype=tf.float32, name=None)
#   139625025577296: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   139625025574992: TensorSpec(shape=(3, 3, 256, 256), dtype=tf.float32, name=None)
#   139625025573840: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   139625025575376: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139625025575568: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139625025578064: TensorSpec(shape=(1, 1, 768, 512), dtype=tf.float32, name=None)
#   139625025576144: TensorSpec(shape=(512,), dtype=tf.float32, name=None)
#   139625025578256: TensorSpec(shape=(1, 1, 512, 256), dtype=tf.float32, name=None)
#   139625025576528: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   139625025578448: TensorSpec(shape=(1, 1, 1024, 512), dtype=tf.float32, name=None)
#   139625025577680: TensorSpec(shape=(512,), dtype=tf.float32, name=None)
#   139625025577488: TensorSpec(shape=(1, 1, 768, 256), dtype=tf.float32, name=None)
#   139625025578640: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   139625025579408: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139625025579216: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139625025580176: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   139625025581520: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   139625025578832: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   139625025579024: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   139625025579600: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139625025579792: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139625025581904: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   139625025580752: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   139625025581712: TensorSpec(shape=(1, 1, 384, 128), dtype=tf.float32, name=None)
#   139625025580944: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   139625025582480: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139625025582288: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139625025583248: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   139625025584592: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   139625025582096: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   139625025580368: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   139625025582672: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139625025582864: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139625025584976: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   139625025583824: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   139625025583440: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   139625025584784: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   139625025584016: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   139625026373200: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   139625026373392: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   139625026374736: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139625026374544: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139625026377424: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   139625026378384: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   139625026374352: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   139625026376464: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   139625026375120: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139625026375312: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139625026377232: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   139625026378192: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   139625026374928: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   139625026377040: TensorSpec(shape=(3, 3, 256, 256), dtype=tf.float32, name=None)
#   139625026377616: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   139625026379344: TensorSpec(shape=(1, 1, 768, 512), dtype=tf.float32, name=None)
#   139625026379536: TensorSpec(shape=(512,), dtype=tf.float32, name=None)
#   139625026380880: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139625026380688: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139625026382416: TensorSpec(shape=(3, 3, 256, 256), dtype=tf.float32, name=None)
#   139625026384144: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   139625026380496: TensorSpec(shape=(3, 3, 256, 256), dtype=tf.float32, name=None)
#   139625026383376: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   139625026381264: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139625026381456: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139625026382608: TensorSpec(shape=(1, 1, 768, 512), dtype=tf.float32, name=None)
#   139625026384336: TensorSpec(shape=(512,), dtype=tf.float32, name=None)
#   139625026381072: TensorSpec(shape=(3, 3, 512, 64), dtype=tf.float32, name=None)
#   139625026377808: TensorSpec(shape=(3, 3, 256, 64), dtype=tf.float32, name=None)
#   139625026371664: TensorSpec(shape=(3, 3, 128, 64), dtype=tf.float32, name=None)
#   139625026381840: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   139625026378000: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   139625026371856: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   139625026383568: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   139625026378768: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   139625026372624: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   139625026384528: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   139625026379152: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   139625026373008: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   139625026385104: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   139625026380304: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   139625026374160: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   139625026385296: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   139625026379920: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   139625026373776: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   139625026382032: TensorSpec(shape=(3, 3, 512, 128), dtype=tf.float32, name=None)
#   139625026376272: TensorSpec(shape=(3, 3, 256, 128), dtype=tf.float32, name=None)
#   139625026372048: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   139625026383760: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   139625026375888: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   139625026372240: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   139625026383952: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   139625026378576: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   139625026372432: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   139625026383184: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   139625026378960: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   139625026372816: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   139625026387600: TensorSpec(shape=(1, 1, 16, 1), dtype=tf.float32, name=None)
#   139625026384720: TensorSpec(shape=(1, 1, 128, 2), dtype=tf.float32, name=None)
#   139625026379728: TensorSpec(shape=(1, 1, 128, 2), dtype=tf.float32, name=None)
#   139625026373584: TensorSpec(shape=(1, 1, 128, 2), dtype=tf.float32, name=None)
#   139625026385488: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   139625026386448: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   139625026386064: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   139625026387024: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   139625026384912: TensorSpec(shape=(2,), dtype=tf.float32, name=None)
#   139625026380112: TensorSpec(shape=(2,), dtype=tf.float32, name=None)
#   139625026373968: TensorSpec(shape=(2,), dtype=tf.float32, name=None)
#   139625026386832: TensorSpec(shape=(1, 2, 8400), dtype=tf.float32, name=None)
#   139625026387216: TensorSpec(shape=(1, 2, 8400), dtype=tf.float32, name=None)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1784231871.178283 3816361 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1784231871.178299 3816361 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# I0000 00:00:1784231871.218293 3816361 mlir_graph_optimization_pass.cc:425] MLIR V1 optimization pass is not enabled
# W0000 00:00:1784231893.793195 3816361 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1784231893.793207 3816361 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# TensorFlow SavedModel: export success ✅ 54.5s, saved as '/home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/models/yolov8s_2026_v5/weights/best_saved_model' (106.7 MB)
#
# Export complete (54.8s)
# Results saved to /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/models/yolov8s_2026_v5/weights
# Predict:         yolo predict task=detect model=/home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/models/yolov8s_2026_v5/weights/best_saved_model imgsz=640
# Validate:        yolo val task=detect model=/home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/models/yolov8s_2026_v5/weights/best_saved_model imgsz=640 data=/home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/Oyster-Dataset-2026-1/data.yaml
# Visualize:       https://netron.app
# '/home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/models/yolov8s_2026_v5/weights/best_saved_model'
