# %%
# %pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/reuekennedy/.local/lib/python3.14/site-packages (3.0.3)
# Requirement already satisfied: numpy>=2.3.3 in /usr/local/lib64/python3.14/site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/lib/python3.14/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO
import pandas as pd

# %%
model_path = "/home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/models/yolov8s_2026/weights/best.pt"
dataset = "/home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-1/data.yaml"
results = []
model = YOLO(model_path)

result = model.val(data=dataset, conf=0.25)
results.append({"Run":"yolov8s Val", "Precision":round(result.box.p.mean().item(), 3),
    "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})
# Out:
# Ultralytics 8.4.71 🚀 Python-3.14.5 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4080, 15935MiB)
# Model summary (fused): 73 layers, 11,126,745 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 123.6±32.0 MB/s, size: 32.4 KB)
# val: Scanning /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-1/valid/labels.cache... 362 images, 139 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 362/362 126.5Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 2621, len(boxes) = 2857. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 23/23 12.3it/s 1.9s0.1s
#                    all        362       2857      0.578      0.564      0.482       0.31
#          Oyster-Closed        169        835      0.559      0.492      0.397      0.234
#   Oyster-Indeterminate        191       1672      0.596       0.61      0.526      0.345
#            Oyster-Open        117        350      0.579      0.589      0.521      0.351
# Speed: 0.6ms preprocess, 2.6ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/val-48

# %%
result = model.val(data=dataset, split="test", conf=0.25)
results.append({"Run":"yolov8s Test", "Precision":round(result.box.p.mean().item(), 3),
    "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})
# Out:
# Ultralytics 8.4.71 🚀 Python-3.14.5 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4080, 15935MiB)
# val: Fast image access ✅ (ping: 0.1±0.1 ms, read: 238.8±79.0 MB/s, size: 38.4 KB)
# val: Scanning /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-1/test/labels.cache... 1929 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1929/1929 1.0Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 121/121 15.4it/s 7.9s0.1s
#                    all       1929      24046      0.345      0.417      0.236      0.125
#          Oyster-Closed       1799       7829      0.366      0.457      0.289      0.168
#   Oyster-Indeterminate       1929      12534      0.316      0.389      0.159     0.0681
#            Oyster-Open       1401       3683      0.352      0.405       0.26      0.138
# Speed: 0.3ms preprocess, 2.3ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/val-49

# %%
model_path = "/home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/models/yolov8m_2026/weights/best.pt"
model = YOLO(model_path)

result = model.val(data=dataset, conf=0.25)
results.append({"Run":"yolov8m Val", "Precision":round(result.box.p.mean().item(), 3),
    "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})
# Out:
# Ultralytics 8.4.71 🚀 Python-3.14.5 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4080, 15935MiB)
# Model summary (fused): 93 layers, 25,841,497 parameters, 0 gradients, 78.7 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4957.3±1073.1 MB/s, size: 51.8 KB)
# val: Scanning /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-1/valid/labels.cache... 362 images, 139 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 362/362 189.8Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 2621, len(boxes) = 2857. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 23/23 8.8it/s 2.6s<0.2s
#                    all        362       2857      0.595      0.552      0.476      0.312
#          Oyster-Closed        169        835      0.535      0.463       0.37      0.229
#   Oyster-Indeterminate        191       1672      0.636      0.602      0.526      0.351
#            Oyster-Open        117        350      0.614      0.591      0.531      0.357
# Speed: 0.4ms preprocess, 5.3ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/val-50

# %%
result = model.val(data=dataset, split="test", conf=0.25)
results.append({"Run":"yolov8m Test", "Precision":round(result.box.p.mean().item(), 3),
    "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})
# Out:
# Ultralytics 8.4.71 🚀 Python-3.14.5 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4080, 15935MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3895.6±1516.9 MB/s, size: 36.2 KB)
# val: Scanning /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-1/test/labels.cache... 1929 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1929/1929 1.6Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 121/121 9.6it/s 12.7s<0.2s
#                    all       1929      24046       0.38      0.402      0.253      0.145
#          Oyster-Closed       1799       7829      0.432       0.49      0.331      0.216
#   Oyster-Indeterminate       1929      12534      0.327      0.339      0.143     0.0617
#            Oyster-Open       1401       3683       0.38      0.375      0.286      0.158
# Speed: 0.3ms preprocess, 5.1ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/val-51

# %%
model_path = "/home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/models/yolov8n_2026/weights/best.pt"
model = YOLO(model_path)

result = model.val(data=dataset, conf=0.25)
results.append({"Run":"yolov8n Val", "Precision":round(result.box.p.mean().item(), 3),
    "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})
# Out:
# Ultralytics 8.4.71 🚀 Python-3.14.5 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4080, 15935MiB)
# Model summary (fused): 73 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4794.2±821.6 MB/s, size: 50.7 KB)
# val: Scanning /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-1/valid/labels.cache... 362 images, 139 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 362/362 253.1Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 2621, len(boxes) = 2857. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 23/23 14.7it/s 1.6s0.0s
#                    all        362       2857      0.571      0.538      0.454      0.294
#          Oyster-Closed        169        835      0.529      0.453      0.346      0.211
#   Oyster-Indeterminate        191       1672      0.575      0.599      0.503      0.329
#            Oyster-Open        117        350       0.61      0.563      0.512      0.343
# Speed: 0.6ms preprocess, 2.2ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/val-52

# %%
result = model.val(data=dataset, split="test", conf=0.25)
results.append({"Run":"yolov8n Test", "Precision":round(result.box.p.mean().item(), 3),
    "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})
# Out:
# Ultralytics 8.4.71 🚀 Python-3.14.5 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4080, 15935MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3384.9±1301.4 MB/s, size: 31.8 KB)
# val: Scanning /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-1/test/labels.cache... 1929 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1929/1929 899.0Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 121/121 20.4it/s 5.9s0.1s
#                    all       1929      24046       0.36      0.405      0.226      0.125
#          Oyster-Closed       1799       7829      0.363      0.415       0.25      0.152
#   Oyster-Indeterminate       1929      12534      0.327      0.434       0.18      0.077
#            Oyster-Open       1401       3683      0.391      0.367      0.247      0.147
# Speed: 0.3ms preprocess, 1.2ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/val-53

# %%
model_path = "/home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/models/yolov8s_2026_v2/weights/best.pt"
model = YOLO(model_path)

result = model.val(data=dataset, conf=0.25)
results.append({"Run":"yolov8s_v2 Val", "Precision":round(result.box.p.mean().item(), 3),
    "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})
# Out:
# Ultralytics 8.4.71 🚀 Python-3.14.5 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4080, 15935MiB)
# Model summary (fused): 73 layers, 11,126,745 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4571.3±493.0 MB/s, size: 46.6 KB)
# val: Scanning /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-1/valid/labels.cache... 362 images, 139 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 362/362 216.9Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 2621, len(boxes) = 2857. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 23/23 12.4it/s 1.9s0.1s
#                    all        362       2857      0.559      0.522      0.422      0.278
#          Oyster-Closed        169        835      0.533      0.436      0.323      0.199
#   Oyster-Indeterminate        191       1672      0.559      0.583      0.489      0.326
#            Oyster-Open        117        350      0.586      0.546      0.455      0.309
# Speed: 0.6ms preprocess, 3.0ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/val-54

# %%
result = model.val(data=dataset, split="test", conf=0.25)
results.append({"Run":"yolov8s_v2 Test", "Precision":round(result.box.p.mean().item(), 3),
    "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})
# Out:
# Ultralytics 8.4.71 🚀 Python-3.14.5 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4080, 15935MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1727.4±517.7 MB/s, size: 33.0 KB)
# val: Scanning /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-1/test/labels.cache... 1929 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1929/1929 809.1Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 121/121 15.2it/s 8.0s0.0s
#                    all       1929      24046      0.311      0.394      0.197      0.121
#          Oyster-Closed       1799       7829      0.309       0.34      0.183      0.127
#   Oyster-Indeterminate       1929      12534      0.309      0.501      0.204     0.0967
#            Oyster-Open       1401       3683      0.313      0.339      0.204      0.139
# Speed: 0.3ms preprocess, 2.3ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/val-55

# %%
model_path = "/home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/models/yolov8m_2026_v2/weights/best.pt"
model = YOLO(model_path)

result = model.val(data=dataset, conf=0.25)
results.append({"Run":"yolov8m_v2 Val", "Precision":round(result.box.p.mean().item(), 3),
    "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})
# Out:
# Ultralytics 8.4.71 🚀 Python-3.14.5 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4080, 15935MiB)
# Model summary (fused): 93 layers, 25,841,497 parameters, 0 gradients, 78.7 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4424.3±970.8 MB/s, size: 46.7 KB)
# val: Scanning /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-1/valid/labels.cache... 362 images, 139 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 362/362 216.9Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 2621, len(boxes) = 2857. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 23/23 8.5it/s 2.7s<0.2s
#                    all        362       2857      0.563      0.498      0.414      0.274
#          Oyster-Closed        169        835      0.501       0.39      0.297      0.183
#   Oyster-Indeterminate        191       1672       0.58      0.583      0.488      0.326
#            Oyster-Open        117        350      0.607      0.521      0.458      0.313
# Speed: 0.5ms preprocess, 5.5ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/val-56

# %%
result = model.val(data=dataset, split="test", conf=0.25)
results.append({"Run":"yolov8m_v2 Test", "Precision":round(result.box.p.mean().item(), 3),
    "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})
# Out:
# Ultralytics 8.4.71 🚀 Python-3.14.5 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4080, 15935MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3552.5±917.4 MB/s, size: 35.9 KB)
# val: Scanning /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-1/test/labels.cache... 1929 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1929/1929 1.0Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 121/121 9.5it/s 12.8s<0.2s
#                    all       1929      24046       0.35      0.399      0.202      0.118
#          Oyster-Closed       1799       7829      0.342      0.348      0.188      0.122
#   Oyster-Indeterminate       1929      12534      0.332      0.482      0.211     0.0975
#            Oyster-Open       1401       3683      0.377      0.367      0.208      0.134
# Speed: 0.3ms preprocess, 5.1ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/val-57

# %%
model_path = "/home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/models/yolov8n_2026_v2/weights/best.pt"
model = YOLO(model_path)

result = model.val(data=dataset, conf=0.25)
results.append({"Run":"yolov8n_v2 Val", "Precision":round(result.box.p.mean().item(), 3),
    "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})
# Out:
# Ultralytics 8.4.71 🚀 Python-3.14.5 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4080, 15935MiB)
# Model summary (fused): 73 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4629.2±686.1 MB/s, size: 44.3 KB)
# val: Scanning /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-1/valid/labels.cache... 362 images, 139 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 362/362 216.9Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 2621, len(boxes) = 2857. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 23/23 15.0it/s 1.5s0.0s
#                    all        362       2857      0.576      0.471      0.399       0.26
#          Oyster-Closed        169        835      0.551      0.368      0.294      0.181
#   Oyster-Indeterminate        191       1672      0.561      0.556       0.47      0.308
#            Oyster-Open        117        350      0.617      0.489      0.432      0.291
# Speed: 0.4ms preprocess, 2.3ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/val-58

# %%
result = model.val(data=dataset, split="test", conf=0.25)
results.append({"Run":"yolov8n_v2 Test", "Precision":round(result.box.p.mean().item(), 3),
    "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})
# Out:
# Ultralytics 8.4.71 🚀 Python-3.14.5 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4080, 15935MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4608.2±1404.2 MB/s, size: 43.0 KB)
# val: Scanning /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-1/test/labels.cache... 1929 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1929/1929 1.2Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 121/121 20.1it/s 6.0s0.1s
#                    all       1929      24046      0.335      0.382      0.178     0.0996
#          Oyster-Closed       1799       7829      0.277      0.329      0.164      0.103
#   Oyster-Indeterminate       1929      12534      0.321      0.515      0.206     0.0978
#            Oyster-Open       1401       3683      0.406      0.302      0.165     0.0982
# Speed: 0.3ms preprocess, 1.2ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/val-59

# %%
model_path = "/home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/models/yolov8s_2026_v3/weights/best.pt"
dataset = "/home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-3/data.yaml"
model = YOLO(model_path)

result = model.val(data=dataset, conf=0.25)
results.append({"Run":"yolov8s_v3 Val", "Precision":round(result.box.p.mean().item(), 3),
    "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})
# Out:
# Ultralytics 8.4.71 🚀 Python-3.14.5 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4080, 15935MiB)
# Model summary (fused): 73 layers, 11,126,358 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.1 ms, read: 269.7±92.2 MB/s, size: 40.9 KB)
# val: Scanning /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-3/valid/labels.cache... 362 images, 139 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 362/362 216.9Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 2620, len(boxes) = 2856. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 23/23 13.3it/s 1.7s0.0s
#                    all        362       2856       0.74      0.626      0.609      0.397
#          Oyster-Closed        211       2348      0.698      0.608      0.591      0.387
#            Oyster-Open        141        508      0.782      0.644      0.627      0.407
# Speed: 0.4ms preprocess, 2.0ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/val-60

# %%
result = model.val(data=dataset, split="test", conf=0.25)
results.append({"Run":"yolov8s_v3 Test", "Precision":round(result.box.p.mean().item(), 3),
    "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})
# Out:
# Ultralytics 8.4.71 🚀 Python-3.14.5 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4080, 15935MiB)
# val: Fast image access ✅ (ping: 0.1±0.1 ms, read: 99.3±35.2 MB/s, size: 26.4 KB)
# val: Scanning /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-3/test/labels... 1929 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1929/1929 2.7Kit/s 0.7s0.0s
# val: New cache created: /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-3/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 121/121 16.1it/s 7.5s0.0s
#                    all       1929      24101      0.521       0.56      0.425       0.25
#          Oyster-Closed       1929      18043      0.528      0.606      0.464      0.267
#            Oyster-Open       1465       6058      0.514      0.515      0.386      0.233
# Speed: 0.3ms preprocess, 2.3ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/val-61

# %%
model_path = "/home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/models/yolov8m_2026_v3/weights/best.pt"
model = YOLO(model_path)

result = model.val(data=dataset, conf=0.25)
results.append({"Run":"yolov8m_v3 Val", "Precision":round(result.box.p.mean().item(), 3),
    "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})
# Out:
# Ultralytics 8.4.71 🚀 Python-3.14.5 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4080, 15935MiB)
# Model summary (fused): 93 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3310.7±1080.0 MB/s, size: 33.6 KB)
# val: Scanning /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-3/valid/labels.cache... 362 images, 139 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 362/362 14.1Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 2620, len(boxes) = 2856. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 23/23 9.1it/s 2.5s<0.2s
#                    all        362       2856      0.647      0.701      0.618        0.4
#          Oyster-Closed        211       2348      0.633      0.695        0.6      0.389
#            Oyster-Open        141        508      0.661      0.707      0.636      0.411
# Speed: 0.4ms preprocess, 4.7ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/val-48

# %%
result = model.val(data=dataset, split="test", conf=0.50)
results.append({"Run":"yolov8m_v3 Test", "Precision":round(result.box.p.mean().item(), 3),
    "Recall":round(result.box.r.mean().item(), 3), "mAP@0.5":round(result.box.map50.mean().item(), 3)})
# Out:
# Ultralytics 8.4.71 🚀 Python-3.14.5 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4080, 15935MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1666.5±509.6 MB/s, size: 30.2 KB)
# val: Scanning /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/2026-Oyster-Dataset-3/test/labels.cache... 1929 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1929/1929 1.2Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 121/121 9.9it/s 12.3s<0.1s
#                    all       1929      24101      0.619      0.463      0.374       0.23
#          Oyster-Closed       1929      18043      0.631      0.462      0.371      0.219
#            Oyster-Open       1465       6058      0.608      0.463      0.378       0.24
# Speed: 0.3ms preprocess, 4.8ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to /home/reuekennedy/Oyster-Video-Monitoring-System-2026/YOLO_testing/2026_model/runs/detect/val-50

# %%
df = pd.DataFrame(results)
df_sorted = df.sort_values(by="mAP@0.5", ascending=False).reset_index(drop=True)
print("\n2025 Model Metrics")
print(df_sorted)
# Out:
# 2025 Model Metrics
#                 Run  Precision  Recall  mAP@0.5
# 0    yolov8m_v3 Val      0.647   0.701    0.618
# 1    yolov8s_v3 Val      0.740   0.626    0.609
# 2       yolov8s Val      0.578   0.564    0.482
# 3       yolov8m Val      0.595   0.552    0.476
# 4       yolov8n Val      0.571   0.538    0.454
# 5   yolov8m_v3 Test      0.543   0.558    0.430
# 6   yolov8s_v3 Test      0.521   0.560    0.425
# 7    yolov8s_v2 Val      0.559   0.522    0.422
# 8    yolov8m_v2 Val      0.563   0.498    0.414
# 9    yolov8n_v2 Val      0.576   0.471    0.399
# 10     yolov8m Test      0.380   0.402    0.253
# 11     yolov8s Test      0.345   0.417    0.236
# 12     yolov8n Test      0.360   0.405    0.226
# 13  yolov8m_v2 Test      0.350   0.399    0.202
# 14  yolov8s_v2 Test      0.311   0.394    0.197
# 15  yolov8n_v2 Test      0.335   0.382    0.178
